# %%
import pandas as pd
df= pd.read_csv('Datasets/NHANES.csv')
df
# Out:
#          ID SurveyYr  Gender  Age AgeDecade  AgeMonths    Race1    Race3  \
# 0     51624  2009_10    male   34     30-39      409.0    White      NaN
# 1     51624  2009_10    male   34     30-39      409.0    White      NaN
# 2     51624  2009_10    male   34     30-39      409.0    White      NaN
# 3     51625  2009_10    male    4       0-9       49.0    Other      NaN
# 4     51630  2009_10  female   49     40-49      596.0    White      NaN
# ...     ...      ...     ...  ...       ...        ...      ...      ...
# 9995  71909  2011_12    male   28     20-29        NaN  Mexican  Mexican
# 9996  71910  2011_12  female    0       0-9        5.0    White    White
# 9997  71911  2011_12    male   27     20-29        NaN  Mexican  Mexican
# 9998  71915  2011_12    male   60     60-69        NaN    White    White
# 9999  71915  2011_12    male   60     60-69        NaN    White    White
#
#            Education MaritalStatus  ... RegularMarij  AgeRegMarij  HardDrugs  \
# ...

# %%
df_male = df[df['Gender']=='male']
df_male
# Out:
#          ID SurveyYr Gender  Age AgeDecade  AgeMonths    Race1    Race3  \
# 0     51624  2009_10   male   34     30-39      409.0    White      NaN
# 1     51624  2009_10   male   34     30-39      409.0    White      NaN
# 2     51624  2009_10   male   34     30-39      409.0    White      NaN
# 3     51625  2009_10   male    4       0-9       49.0    Other      NaN
# 5     51638  2009_10   male    9       0-9      115.0    White      NaN
# ...     ...      ...    ...  ...       ...        ...      ...      ...
# 9994  71909  2011_12   male   28     20-29        NaN  Mexican  Mexican
# 9995  71909  2011_12   male   28     20-29        NaN  Mexican  Mexican
# 9997  71911  2011_12   male   27     20-29        NaN  Mexican  Mexican
# 9998  71915  2011_12   male   60     60-69        NaN    White    White
# 9999  71915  2011_12   male   60     60-69        NaN    White    White
#
#            Education MaritalStatus  ... RegularMarij  AgeRegMarij  HardDrugs  \
# ...

# %%
height = df_male["Height"].dropna()

# %%
x_value = height

import matplotlib.pyplot as plt

fig, axs = plt.subplots(figsize=(12,8))
axs.hist(x_value, color="SkyBlue", edgecolor="Black")
plt.title("Heights of Males in the U.S [cm]", fontsize=20)
axs.set_xlabel("Height of Males in the U.S [cm]", fontsize=18)
axs.set_ylabel("Frequency", fontsize=18)
axs.tick_params(labelsize=15)
plt.show()

# %%
import pandas as pd
df = pd.read_csv('Datasets/NHANES.csv')

# %%
import numpy as np

# %%
male_df.head()
# Out:
#    Gender  Age  Height
# 0    male   34   164.7
# 1    male   34   164.7
# 2    male   34   164.7
# 10   male   66   169.5
# 11   male   58   181.9

# %%
height =male_df["Height"]

mean = np.mean(height)
variance = np.var(height)
std = np.std(height)

print("Male adult average height:", mean)
print("Variance of male adult height:", variance)
print("Standard deviation of male adult height:", std)
# Out:
# Male adult average height: 175.78927355278043
# Variance of male adult height: 55.92104271858525
# Standard deviation of male adult height: 7.478037357394335

# %%
female_df.head()
# Out:
#     Gender  Age  Height
# 4   female   49   168.4
# 7   female   45   166.7
# 8   female   45   166.7
# 9   female   45   166.7
# 14  female   58   148.1

# %%
height =female_df["Height"]

mean = np.mean(height)
variance = np.var(height)
std = np.std(height)

print("female adult average height:", mean)
print("Variance of female adult height:", variance)
print("Standard deviation of female adult height:", std)
# Out:
# female adult average height: 162.04283761618387
# Variance of female adult height: 53.21568544164709
# Standard deviation of female adult height: 7.2949081859641725

# %%
df_female = df[df['Gender']=='female']
df_female
# Out:
#       Gender  Age  Height
# 4     female   49   168.4
# 7     female   45   166.7
# 8     female   45   166.7
# 9     female   45   166.7
# 13    female   10   141.8
# ...      ...  ...     ...
# 9982  female   20   164.2
# 9986  female   60   162.9
# 9987  female   65   154.7
# 9991  female   66   159.0
# 9992  female   66   159.0
#
# [4847 rows x 3 columns]

# %%
height = df_female["Height"].dropna()

# %%
x_value = height

import matplotlib.pyplot as plt

fig, axs = plt.subplots(figsize=(12,8))
axs.hist(x_value, color="g", edgecolor="Black")
plt.title("Height of Females in the U.S[cm]", fontsize=20)
axs.set_xlabel("Height[cm]", fontsize=18)
axs.set_ylabel("Frequency", fontsize=18)
axs.tick_params(labelsize=15)
plt.show()

# %%
import pandas as pd
import numpy as no
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Datasets/NHANES.csv')
df = df[['Gender', 'Age', 'Height']]
df = df.dropna()

# %%
adult = df['Age'] >= 20


male = df['Gender'] == 'male'
female = df['Gender'] == 'female'


male_df = df[adult & male]
female_df = df[adult & female]

# %%
male_height = male_df['Height']
female_height = female_df['Height']

# %%
fig, axs = plt.subplots(figsize=(12,8))
axs.boxplot([male_height, female_height])
plt.title('Height distribution of the U.S.', fontsize=20)
axs.set_xticklabels(['Male Adult','Female Adult'])
axs.set_ylabel('Height [cm]', fontsize=18)
axs.tick_params(labelsize=15)
plt.show()

# %%
height = male_df['Height']

maximum = np.max(height)
minimum = np.min(height)
median = np.median(height)

q1 = np.percentile(height, 25, interpolation='midpoint')
q3 = np.percentile(height, 75, interpolation='midpoint')

print("Max male adult height:", maximum)
print("Min male adult height:", minimum)
print("The median is:", median)
print("The interquartile range is:", q3-q1)
# Out:
# Max male adult height: 200.4
# Min male adult height: 149.4
# The median is: 175.6
# The interquartile range is: 9.599999999999994

# %%
height = female_df['Height']

maximum = np.max(height)
minimum = np.min(height)
median = np.median(height)

q1 = np.percentile(height, 25, interpolation='midpoint')
q3 = np.percentile(height, 75, interpolation='midpoint')

print("Max female adult height:", maximum)
print("Min female adult height:", minimum)
print("The median is:", median)
print("The interquartile range is:", q3-q1)
# Out:
# Max female adult height: 184.5
# Min female adult height: 134.5
# The median is: 162.1
# The interquartile range is: 9.75
